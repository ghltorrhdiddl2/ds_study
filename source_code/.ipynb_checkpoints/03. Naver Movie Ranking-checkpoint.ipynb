# %% [markdown]
# # 03. Naver Movie Ranking

# %% [markdown]
# ## 1. 네이버 영화 평점 사이트 분석
# - https://movie.naver.com/
# - 영화랭킹 탭 이동
# - 영화랭킹에서 평점순(현재상영영화) 선택

# %% [markdown]
# ```
# https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20221017
# ```
#
# - 웹 페이지 주소에는 많은 정보가 담겨있습니다.
# - 원하는 정보를 얻기 위해서 변화시켜줘야 하는 주소의 규칙을 찾을 수 있습니다.
# - 여기에서는 날짜 정보를 변경해주면 해당 페이지에 접근이 가능합니다.

# %%
# requerements
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20221017"
res = urlopen(url)
# res.status
soup = BeautifulSoup(res, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
#    <meta content="네이버영화 " property="me2:post_tag">
#     <meta content="네이버영화" property="me2:category1"/>
#     <meta content="" property="me2:category2"/>
#     <meta content="랭킹 : 네이버 영화" property="og:title"/>
#     <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
#     <meta content="article" property="og:type"/>
#     <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&amp;date=20221017" property="og:url"/>
#     <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/>
#     <!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# ...

# %%
# 영화 제목 태그
soup.find_all("div", "tit5")   # soup.select(".tit5")
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=81888" title="탑건: 매버릭">탑건: 매버릭</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=217719" title="명탐정 코난: 할로윈의 신부">명탐정 코난: 할로윈의 신부</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=219812" title="극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교">극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=187320" title="씽2게더">씽2게더</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=187821" title="인생은 아름다워">인생은 아름다워</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=213418" title="사잇소리">사잇소리</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=213733" title="극장판 주술회전 0">극장판 주술회전 0</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=10105" title="사랑은 비를 타고">사랑은 비를 타고</a>
#  </div>,
#  <div class="tit5">
# ...

# %%
len(soup.find_all("div", "tit5"))
# Out:
# 50

# %%
soup.find_all("div", "tit5")[0]
# Out:
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=81888" title="탑건: 매버릭">탑건: 매버릭</a>
# </div>

# %%
# 1
soup.find_all("div", "tit5")[0].a.string
# Out:
# '탑건: 매버릭'

# %%
# 2
soup.select(".tit5")[0].find("a").text
# Out:
# '탑건: 매버릭'

# %%
# 3
soup.select(".tit5")[0].select_one("a").get_text()
# Out:
# '탑건: 매버릭'

# %%
# 영화 평점 태그
soup.find_all("td", "point")  # soup.select(".point")
# Out:
# [<td class="point">9.77</td>,
#  <td class="point">9.46</td>,
#  <td class="point">9.42</td>,
#  <td class="point">9.39</td>,
#  <td class="point">9.26</td>,
#  <td class="point">9.26</td>,
#  <td class="point">9.23</td>,
#  <td class="point">9.23</td>,
#  <td class="point">9.19</td>,
#  <td class="point">9.19</td>,
#  <td class="point">9.06</td>,
#  <td class="point">9.03</td>,
#  <td class="point">8.97</td>,
#  <td class="point">8.96</td>,
#  <td class="point">8.91</td>,
#  <td class="point">8.89</td>,
#  <td class="point">8.81</td>,
#  <td class="point">8.80</td>,
#  <td class="point">8.80</td>,
#  <td class="point">8.79</td>,
#  <td class="point">8.76</td>,
#  <td class="point">8.74</td>,
#  <td class="point">8.73</td>,
#  <td class="point">8.73</td>,
#  <td class="point">8.68</td>,
#  <td class="point">8.68</td>,
#  <td class="point">8.67</td>,
#  <td class="point">8.64</td>,
#  <td class="point">8.60</td>,
#  <td class="point">8.59</td>,
#  <td class="point">8.38</td>,
# ...

# %%
len(soup.find_all("td", "point"))
# Out:
# 50

# %%
# 1
soup.find_all("td", "point")[0].string
# Out:
# '9.77'

# %%
# 2
soup.find_all("td", class_="point")[0].text
# Out:
# '9.77'

# %%
# 3
soup.select("td.point")[0].get_text()
# Out:
# '9.77'

# %%
# 영화제목 리스트
end = len(soup.find_all("div", "tit5"))
movie_name = []

for n in range(0, end):
    movie_name.append(soup.find_all("div", "tit5")[n].a.string)
movie_name
# Out:
# ['탑건: 매버릭',
#  '명탐정 코난: 할로윈의 신부',
#  '극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교',
#  '씽2게더',
#  '인생은 아름다워',
#  '사잇소리',
#  '극장판 주술회전 0',
#  '사랑은 비를 타고',
#  '너에게 가는 길',
#  '해피 투게더',
#  '꽃다발 같은 사랑을 했다',
#  '택시운전사',
#  '이별의 아침에 약속의 꽃을 장식하자',
#  '윤희에게',
#  '마담 프루스트의 비밀정원',
#  '중경삼림',
#  '너의 이름은.',
#  '화양연화',
#  '아멜리에',
#  '소공녀',
#  '한산: 용의 출현',
#  '벌새',
#  '본 투 비 블루',
#  '블레이드 러너',
#  '접속',
#  '헤어질 결심',
#  '건축학개론',
#  '지금, 이대로가 좋아요',
#  '공조2: 인터내셔날',
#  '육사오(6/45)',
#  '헌트',
#  '너의 췌장을 먹고 싶어',
#  '초속5센티미터',
#  '큐어',
#  '비비안 마이어를 찾아서',
#  '리스본행 야간열차',
#  '에브리씽 에브리웨어 올 앳 원스',
#  '언어의 정원',
#  '테넷',
#  '릴리 슈슈의 모든 것',
#  '날씨의 아이',
#  '듄',
#  '사랑할 땐 누구나 최악이 된다',
#  '스마일',
#  '미니언즈2',
#  '썸머 필름을 타고!',
#  '오펀: 천사의 탄생',
#  '대무가',
#  '컴백홈',
#  '비바리움']

# %%
# list comprehension
movie_name = [soup.select(".tit5")[n].a.text for n in range(0, end)]
movie_name
# Out:
# ['탑건: 매버릭',
#  '명탐정 코난: 할로윈의 신부',
#  '극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교',
#  '씽2게더',
#  '인생은 아름다워',
#  '사잇소리',
#  '극장판 주술회전 0',
#  '사랑은 비를 타고',
#  '너에게 가는 길',
#  '해피 투게더',
#  '꽃다발 같은 사랑을 했다',
#  '택시운전사',
#  '이별의 아침에 약속의 꽃을 장식하자',
#  '윤희에게',
#  '마담 프루스트의 비밀정원',
#  '중경삼림',
#  '너의 이름은.',
#  '화양연화',
#  '아멜리에',
#  '소공녀',
#  '한산: 용의 출현',
#  '벌새',
#  '본 투 비 블루',
#  '블레이드 러너',
#  '접속',
#  '헤어질 결심',
#  '건축학개론',
#  '지금, 이대로가 좋아요',
#  '공조2: 인터내셔날',
#  '육사오(6/45)',
#  '헌트',
#  '너의 췌장을 먹고 싶어',
#  '초속5센티미터',
#  '큐어',
#  '비비안 마이어를 찾아서',
#  '리스본행 야간열차',
#  '에브리씽 에브리웨어 올 앳 원스',
#  '언어의 정원',
#  '테넷',
#  '릴리 슈슈의 모든 것',
#  '날씨의 아이',
#  '듄',
#  '사랑할 땐 누구나 최악이 된다',
#  '스마일',
#  '미니언즈2',
#  '썸머 필름을 타고!',
#  '오펀: 천사의 탄생',
#  '대무가',
#  '컴백홈',
#  '비바리움']

# %%
# 영화 평점 리스트
end = len(soup.find_all("td", "point"))
movie_point = [soup.select(".point")[n].text for n in range(0, end)]
movie_point
# Out:
# ['9.77',
#  '9.46',
#  '9.42',
#  '9.39',
#  '9.26',
#  '9.26',
#  '9.23',
#  '9.23',
#  '9.19',
#  '9.19',
#  '9.06',
#  '9.03',
#  '8.97',
#  '8.96',
#  '8.91',
#  '8.89',
#  '8.81',
#  '8.80',
#  '8.80',
#  '8.79',
#  '8.76',
#  '8.74',
#  '8.73',
#  '8.73',
#  '8.68',
#  '8.68',
#  '8.67',
#  '8.64',
#  '8.60',
#  '8.59',
#  '8.38',
#  '8.37',
#  '8.36',
#  '8.32',
#  '8.32',
#  '8.31',
#  '8.22',
#  '8.17',
#  '8.14',
#  '8.12',
#  '7.96',
#  '7.96',
#  '7.77',
#  '7.74',
#  '7.69',
#  '7.55',
#  '6.57',
#  '6.27',
#  '6.26',
#  '6.05']

# %%
# 전체 데이터 수 확인
len(movie_name), len(movie_point)
# Out:
# (50, 50)

# %% [markdown]
# ## 2. 자동화를 위한 코드

# %% [markdown]
# ```
# https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20221017
# ```
# - 날짜만 변경하면 우리가 원하는 기간 만큼 데이터를 얻을 수 있습니다.

# %%
date = pd.date_range("2021.0101", periods=100, freq="D")
date
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14', '2021-01-15', '2021-01-16',
#                '2021-01-17', '2021-01-18', '2021-01-19', '2021-01-20',
#                '2021-01-21', '2021-01-22', '2021-01-23', '2021-01-24',
#                '2021-01-25', '2021-01-26', '2021-01-27', '2021-01-28',
#                '2021-01-29', '2021-01-30', '2021-01-31', '2021-02-01',
#                '2021-02-02', '2021-02-03', '2021-02-04', '2021-02-05',
#                '2021-02-06', '2021-02-07', '2021-02-08', '2021-02-09',
#                '2021-02-10', '2021-02-11', '2021-02-12', '2021-02-13',
#                '2021-02-14', '2021-02-15', '2021-02-16', '2021-02-17',
#                '2021-02-18', '2021-02-19', '2021-02-20', '2021-02-21',
# ...

# %%
date[0]
# Out:
# Timestamp('2021-01-01 00:00:00', freq='D')

# %%
date[0].strftime("%Y-%m-%d")
# Out:
# '2021-01-01'

# %%
date[0].strftime("%Y.%m.%d")
# Out:
# '2021.01.01'

# %%
# 문자열 format
test_string = "Hi, I'm {name}"
test_string.format(name="Pink")
test_string.format(name="Harry")
# Out:
# "Hi, I'm Harry"

# %%
import time
from tqdm import tqdm   # 진행도를 bar형태로 시각화

movie_date = []
movie_name = []
movie_point = []

for today in tqdm(date):
    url = "https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date={date}"
    res = urlopen(url.format(date = today.strftime("%Y%m%d")))
    soup = BeautifulSoup(res, "html.parser")
    
    end = len(soup.find_all("td", "point"))
    
    movie_date.extend([today for _ in range(0, end)])
    movie_name.extend([soup.select("div.tit5")[n].a.text for n in range(0, end)])
    movie_point.extend([soup.find_all("td", "point")[n].string for n in range(0, end)])
    
    time.sleep(0.5)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [03:32<00:00,  2.12s/it]

# %%
len(movie_date), len(movie_name), len(movie_point)   # 갯수 맞는지 확인
# Out:
# (4793, 4793, 4793)

# %%
movie_point[:5]
# Out:
# ['9.59', '9.52', '9.49', '9.40', '9.39']

# %%
movie_name[:5]
# Out:
# ['가나의 혼인잔치: 언약', '언플랜드', '극장판 바이올렛 에버가든', '부활: 그 증거', '소년시절의 너']

# %%
movie = pd.DataFrame({
    "date": movie_date,
    "name": movie_name,
    "point": movie_point
})
movie.tail()
# Out:
#            date        name point
# 4788 2021-04-10      두번째 사랑  8.00
# 4789 2021-04-10      날씨의 아이  7.95
# 4790 2021-04-10          밀양  7.92
# 4791 2021-04-10    별을 쫓는 아이  7.91
# 4792 2021-04-10  너는 여기에 없었다  7.82

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4793 entries, 0 to 4792
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4793 non-null   datetime64[ns]
#  1   name    4793 non-null   object
#  2   point   4793 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 112.5+ KB

# %%
movie["point"] = movie["point"].astype(float)

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4793 entries, 0 to 4792
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4793 non-null   datetime64[ns]
#  1   name    4793 non-null   object
#  2   point   4793 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 112.5+ KB

# %%
# 데이터 저장
movie.to_csv("../data/03. naver_movie_data.csv", sep=",", encoding="utf-8")

# %%
# 데이터 저장되었는지 확인
df = pd.read_csv("../data/03. naver_movie_data.csv", index_col=0)
df.tail(2)
# Out:
#             date        name  point
# 4791  2021-04-10    별을 쫓는 아이   7.91
# 4792  2021-04-10  너는 여기에 없었다   7.82

# %% [markdown]
# ## 3. 영화 평점 데이터 정리

# %%
import numpy as np
import pandas as pd

# %%
movie = pd.read_csv("../data/03. naver_movie_data.csv", index_col=0)
movie.tail()
# Out:
#             date        name  point
# 4788  2021-04-10      두번째 사랑   8.00
# 4789  2021-04-10      날씨의 아이   7.95
# 4790  2021-04-10          밀양   7.92
# 4791  2021-04-10    별을 쫓는 아이   7.91
# 4792  2021-04-10  너는 여기에 없었다   7.82

# %% [markdown]
# - 영화 이름으로 인덱스를 잡는다.
# - 점수의 합산을 구한다.
# - 100일 간 네이버 영화 평점 합산 기준 베스트&워스트 10 선정

# %%
# piovt table
movie_unique = pd.pivot_table(data=movie, index="name", aggfunc=np.sum)
movie_unique
# Out:
#                point
# name
# 120BPM          2.76
# 1917           62.09
# 800            25.27
# 가나의 혼인잔치: 언약  501.68
# 건축학개론          78.03
# ...              ...
# 해피 투게더        703.29
# 허트 로커         219.32
# 현기증           198.56
# 협상             14.64
# 화양연화          877.12
#
# [190 rows x 1 columns]

# %%
movie_best = movie_unique.sort_values(by="point", ascending=False)  # 내림차순
movie_best.head()
# Out:
#                 point
# name
# 너의 췌장을 먹고 싶어   959.59
# 극장판 바이올렛 에버가든  949.98
# 부활: 그 증거       936.44
# 러브 액츄얼리        893.02
# 화양연화           877.12

# %%
tmp = movie.query("name == ['화양연화']")
tmp
# Out:
#             date  name  point
# 22    2021-01-01  화양연화   8.80
# 70    2021-01-02  화양연화   8.79
# 117   2021-01-03  화양연화   8.75
# 162   2021-01-04  화양연화   8.76
# 205   2021-01-05  화양연화   8.76
# ...          ...   ...    ...
# 4571  2021-04-06  화양연화   8.79
# 4621  2021-04-07  화양연화   8.79
# 4668  2021-04-08  화양연화   8.79
# 4719  2021-04-09  화양연화   8.79
# 4769  2021-04-10  화양연화   8.79
#
# [100 rows x 3 columns]

# %%
# 시각화
import matplotlib.pyplot as plt
from matplotlib import rc

rc("font", family="Malgun Gothic")
# %matplotlib inline

# %%
plt.figure(figsize=(20, 8))   # x 20, y 8
plt.plot(tmp["date"], tmp["point"])   # 선 그래프 x축 날짜, y축 평점 => 날짜에 따른 평점 변화를 선그래프로 표현(시계열)
plt.title("날짜별 평점")
plt.xlabel("날짜")
plt.ylabel("평점")
plt.xticks(rotation="vertical")    # xlabel 세로로 회전
plt.legend(labels=["평점 추이"], loc="best")
plt.show()

# %%
# 상위 10개 영화
movie_best.head(10)
# Out:
#                 point
# name
# 너의 췌장을 먹고 싶어   959.59
# 극장판 바이올렛 에버가든  949.98
# 부활: 그 증거       936.44
# 러브 액츄얼리        893.02
# 화양연화           877.12
# 타오르는 여인의 초상    833.51
# 너의 이름은.        817.40
# 아비정전           814.83
# 찬실이는 복도 많지     785.58
# 러브레터           784.32

# %%
# 하위 10개 영화
movie_best.tail(10)
# Out:
#              point
# name
# 최악의 하루       23.40
# 열혈남아         23.16
# 영웅본색         18.36
# 너는 여기에 없었다   15.64
# 협상           14.64
# 고질라          13.34
# 초미의 관심사       7.37
# 레이니 데이 인 뉴욕   5.54
# 신 고질라         4.97
# 120BPM        2.76

# %%
movie_pivot = pd.pivot_table(data=movie, index="date", columns="name", values="point")
movie_pivot.head()
# Out:
# name        120BPM  1917   800  가나의 혼인잔치: 언약  건축학개론  고질라  고질라 VS. 콩  국가부도의 날  \
# date
# 2021-01-01     NaN   NaN  3.60          9.59    NaN  NaN        NaN      NaN
# 2021-01-02     NaN   NaN  3.60          9.56    NaN  NaN        NaN      NaN
# 2021-01-03     NaN   NaN  3.60          9.54    NaN  NaN        NaN      NaN
# 2021-01-04     NaN   NaN  3.61          9.51    NaN  NaN        NaN      NaN
# 2021-01-05     NaN   NaN  3.62          9.52    NaN  NaN        NaN      NaN
#
# name         굿바이  귀여운 여인  ...   피아노  피아니스트의 전설  하나와 앨리스  해리 포터와 불의 잔  \
# date                      ...
# 2021-01-01  9.04     8.7  ...  8.66        NaN     8.11          NaN
# 2021-01-02  9.04     8.7  ...  8.66        NaN     8.11          NaN
# 2021-01-03  9.04     8.7  ...  8.66        NaN     8.11          NaN
# 2021-01-04  9.04     8.7  ...   NaN        NaN     8.11          NaN
# 2021-01-05  9.04     NaN  ...   NaN        NaN      NaN          NaN
#
# ...

# %%
movie_pivot.to_excel("../data/03. movie_pivot.xlsx")

# %%
import platform
import seaborn as sns
from matplotlib import font_manager, rc

path = "C:Windows/Fonts/malgun.ttf"

if platform.system() == "Darwin":
    rc("font", familiy="Arial Unicode MS")
elif platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc("font", family=font_name)
else:
    print("Unkown system. sorry")

# %%
target_col = ["화양연화", "국가부도의 날", "하나와 앨리스", "늑대와 춤을", "피아노"]
plt.figure(figsize=(20, 8))
plt.title("날짜별 평점")
plt.xlabel("날짜")
plt.ylabel("평점")
plt.xticks(rotation="vertical")
plt.tick_params(bottom="off", labelbottom="off")
plt.plot(movie_pivot[target_col])
plt.legend(target_col, loc="best")
plt.grid()
plt.show()
